# %% [markdown]
# # Wumpus World - RL Training
#
# Train a PPO agent with frame stacking (implicit memory) on a partially observable Wumpus World.

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Image, HTML
from PIL import Image as PILImage

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ## 1. Test Environment

# %%
from wumpus_env import WumpusWorldEnv

env = WumpusWorldEnv(render_mode='rgb_array')
obs, _ = env.reset()

print(f"Observation shape: {obs.shape}")
print("Channels: Agent, Visited, Breeze, Stench, Safe, Danger, Gold, Walls")

# Render
frame = env.render()
plt.figure(figsize=(6, 7))
plt.imshow(frame)
plt.title("Initial State (partial observability)")
plt.axis('off')
plt.tight_layout()
plt.show()

env.close()
# Out:
# Observation shape: (8, 5, 5)
# Channels: Agent, Visited, Breeze, Stench, Safe, Danger, Gold, Walls

# %% [markdown]
# ## 2. Train Agent

# %%
from train import train

# Train with frame stacking
# Adjust timesteps based on your machine (50k-100k recommended)
model, history = train(
    total_timesteps=80000,
    n_envs=4,
    frame_stack=4
)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ==================================================
# Wumpus World - PPO with Frame Stacking
# ==================================================
#
# Envs: 4 parallel, 4 frames stacked
# Output()
# Observation shape: (8, 5, 20)
# Training for 80,000 steps...
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 from train import train
#       3 # Train with frame stacking
#       4 # Adjust timesteps based on your machine (50k-100k recommended)
# ----> 5 model, history = train(
#       6     total_timesteps=80000,
#       7     n_envs=4,
#       8     frame_stack=4
#       9 )
#
# File ~/wumpus/train.py:137, in train(total_timesteps, n_envs, frame_stack, save_dir)
#     133 print("-" * 50)
#     135 callback = ProgressCallback(eval_env=eval_env, eval_freq=2500, verbose=1)
# --> 137 model.learn(total_timesteps=total_timesteps, callback=callback, progress_bar=True)
#     139 print("-" * 50)
#     141 # Save
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:278, in PPO.train(self)
#     276     # Clip grad norm
#     277     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 278     self.policy.optimizer.step()
#     280 self._n_updates += 1
#     281 if not continue_training:
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File ~/wumpus/.venv/lib/python3.12/site-packages/torch/optim/adam.py:447, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     444     device_beta1 = beta1
#     446 # Decay the first and second moment running average coefficient
# --> 447 exp_avg.lerp_(grad, 1 - device_beta1)
#     449 # Nested if is necessary to bypass jitscript rules
#     450 if differentiable and isinstance(beta2, Tensor):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Training Results

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 9))

# Rewards
ax = axes[0, 0]
rewards = history['episode_rewards']
ax.plot(rewards, alpha=0.3, color='steelblue')
if len(rewards) > 50:
    ma = np.convolve(rewards, np.ones(50)/50, mode='valid')
    ax.plot(range(49, len(rewards)), ma, color='darkblue', lw=2, label='MA(50)')
ax.axhline(100, color='green', ls='--', alpha=0.5, label='Gold (+100)')
ax.axhline(-50, color='red', ls='--', alpha=0.5, label='Death (-50)')
ax.set_xlabel('Episode')
ax.set_ylabel('Reward')
ax.set_title('Episode Rewards')
ax.legend()
ax.grid(alpha=0.3)

# Win rate
ax = axes[0, 1]
wins = history['wins']
if len(wins) > 20:
    win_rate = [np.mean(wins[max(0,i-50):i+1])*100 for i in range(len(wins))]
    ax.plot(win_rate, color='forestgreen', lw=2)
    ax.fill_between(range(len(win_rate)), win_rate, alpha=0.3, color='green')
ax.set_xlabel('Episode')
ax.set_ylabel('Win Rate (%)')
ax.set_title('Win Rate (Rolling 50)')
ax.set_ylim(0, 100)
ax.grid(alpha=0.3)

# Exploration
ax = axes[1, 0]
expl = history['exploration_rates']
if len(expl) > 20:
    expl_ma = [np.mean(expl[max(0,i-50):i+1])*100 for i in range(len(expl))]
    ax.plot(expl_ma, color='purple', lw=2)
ax.set_xlabel('Episode')
ax.set_ylabel('Exploration (%)')
ax.set_title('Map Exploration')
ax.set_ylim(0, 100)
ax.grid(alpha=0.3)

# Eval rewards
ax = axes[1, 1]
if history['eval_rewards']:
    ax.plot(history['eval_timesteps'], history['eval_rewards'], 'o-', color='coral', lw=2, ms=8)
ax.set_xlabel('Timesteps')
ax.set_ylabel('Eval Reward')
ax.set_title('Evaluation Performance')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('plots/training_results.png', dpi=150)
plt.show()

print(f"\nFinal Win Rate: {history.get('final_win_rate', 0)*100:.1f}%")

# %% [markdown]
# ## 4. Watch Agent Play

# %%
from train import record_episode

# Record one episode
frames, info = record_episode('models/ppo_wumpus', 'episode_frames')

print(f"\nResult: {'WON!' if info.get('win') else 'LOST'}")
print(f"Explored: {info.get('visited_cells', 0)}/25 cells")

# %%
# Display the episode GIF
Image(filename='episode_frames/episode.gif')

# %%
# Show key frames
n_show = min(8, len(frames))
indices = np.linspace(0, len(frames)-1, n_show, dtype=int)

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
for i, idx in enumerate(indices):
    ax = axes[i//4, i%4]
    ax.imshow(frames[idx])
    ax.set_title(f"Step {idx}")
    ax.axis('off')
plt.suptitle(f"Episode: {'WON!' if info.get('win') else 'LOST'}", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Full Evaluation

# %%
from train import evaluate_and_record

# Run multiple episodes
results = evaluate_and_record('models/ppo_wumpus', n_episodes=20)

# %%
# Show best episode
Image(filename='recordings/best_episode.gif')

# %%
# Results summary
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

rewards = [r['reward'] for r in results]
explored = [r['explored'] for r in results]
wins = [1 if r['win'] else 0 for r in results]

axes[0].bar(range(len(rewards)), rewards, color=['green' if w else 'salmon' for w in wins])
axes[0].axhline(0, color='black', lw=0.5)
axes[0].set_xlabel('Episode')
axes[0].set_ylabel('Reward')
axes[0].set_title('Rewards by Episode')

axes[1].bar(range(len(explored)), explored, color='steelblue')
axes[1].axhline(25, color='green', ls='--', alpha=0.5)
axes[1].set_xlabel('Episode')
axes[1].set_ylabel('Cells')
axes[1].set_title('Exploration by Episode')

win_rate = sum(wins) / len(wins) * 100
axes[2].pie([win_rate, 100-win_rate], labels=['Win', 'Loss'], 
            colors=['forestgreen', 'salmon'], autopct='%.1f%%', startangle=90)
axes[2].set_title(f'Win Rate: {win_rate:.1f}%')

plt.tight_layout()
plt.show()

# %%
print("Done!")
